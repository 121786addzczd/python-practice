# %% [markdown]
# # 株価のデータを折れ線グラフで可視化

# %%
from pandas_datareader import data
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = '2019-11-01'
end = '2020-11-01'

df = data.DataReader('^N225', 'yahoo', start, end)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14019/1914191950.py in <module>
#       2 end = '2020-11-01'
#       3
# ----> 4 df = data.DataReader('^N225', 'yahoo', start, end)
#
# /usr/local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.7/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     376             retry_count=retry_count,
#     377             pause=pause,
# --> 378             session=session,
#     379         ).read()
#     380
#
# /usr/local/lib/python3.7/site-packages/pandas_datareader/base.py in read(self)
# ...

# %%
# !pip install --upgrade pandas-datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# ...
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
# ...

# %% [markdown]
# pandas_datareaderパッケージのDataReader関数を使用してYahoo Financeからデータを読み取る際に発生している模様。エラーメッセージは、JSONのデータ解析中に問題が発生していることを示している。
#
# pandas_datareaderパッケージの最新バージョンでも問題が解決しなかったため、pandas_datareaderパッケージの代わりにyfinanceパッケージを使用

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# ...
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
# ...

# %%
import yfinance as yf

start = '2019-11-01'
end = '2020-11-01'

df = yf.download('^N225', start=start, end=end)
df.head(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2019-11-01  22730.490234  22852.720703  22705.599609  22850.769531
# 2019-11-05  23118.789062  23328.519531  23090.939453  23251.990234
# 2019-11-06  23343.509766  23352.560547  23246.570312  23303.820312
# 2019-11-07  23283.140625  23336.000000  23253.320312  23330.320312
# 2019-11-08  23550.039062  23591.089844  23313.410156  23391.869141
# 2019-11-11  23422.130859  23471.820312  23323.019531  23331.839844
# 2019-11-12  23336.369141  23545.699219  23312.250000  23520.009766
# 2019-11-13  23439.250000  23452.630859  23270.929688  23319.869141
# 2019-11-14  23325.500000  23360.060547  23062.160156  23141.550781
# 2019-11-15  23160.529297  23340.769531  23121.589844  23303.320312
#
#                Adj Close     Volume
# Date
# 2019-11-01  22850.769531   65400000
# 2019-11-05  23251.990234  102100000
# ...

# %%
x = df.index
y = df['Adj Close'] # 終値

plt.plot(x, y)

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([16000., 17000., 18000., 19000., 20000., 21000., 22000., 23000.,
#         24000., 25000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid(axis='x') # x軸のグリッドだけを表示

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid(axis='y') # y軸のグリッドだけを表示

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y, color='red')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y, color='#709B89')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y, linewidth=5)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y, linestyle='dashed') # 波線
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %% [markdown]
# ## X軸とY軸が交わるところにマーカーをつける

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y, marker='o')  # x,yの交わるところにマーカを付ける
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()

# %%
# !pip install japanize_matplotlib  # 日本語表記のためのライブラリをインストール
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# ...
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -andas-datareader (/usr/local/lib/python3.7/site-packages)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
# ...

# %%
import japanize_matplotlib

# %%
plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
# Out:
# Text(0.5, 1.0, '日経平均株価2019-2020')

# %%
df['index_num'] = df.reset_index().index
df.head(20)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-11-01  22730.490234  22852.720703  22705.599609  22850.769531
# 2019-11-05  23118.789062  23328.519531  23090.939453  23251.990234
# 2019-11-06  23343.509766  23352.560547  23246.570312  23303.820312
# 2019-11-07  23283.140625  23336.000000  23253.320312  23330.320312
# 2019-11-08  23550.039062  23591.089844  23313.410156  23391.869141
# 2019-11-11  23422.130859  23471.820312  23323.019531  23331.839844
# 2019-11-12  23336.369141  23545.699219  23312.250000  23520.009766
# 2019-11-13  23439.250000  23452.630859  23270.929688  23319.869141
# 2019-11-14  23325.500000  23360.060547  23062.160156  23141.550781
# 2019-11-15  23160.529297  23340.769531  23121.589844  23303.320312
# 2019-11-18  23304.250000  23420.619141  23271.289062  23416.759766
# 2019-11-19  23366.359375  23389.529297  23244.929688  23292.650391
# 2019-11-20  23176.490234  23303.169922  23086.119141  23148.570312
# ...

# %% [markdown]
# ## グラフに矢印つき注釈（アノテーション）を追加

# %%
import matplotlib.dates as mdates # 時系列データを取得するためにインポート

plt.figure(figsize=(30, 10))
plt.plot(x, y)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.annotate('points',xy=(mdates.date2num(x[10]),y[10]),
              xytext=(mdates.date2num(x[10])+10,24000), fontsize=30, color='red', arrowprops=dict(color='black'))
plt.savefig('N225.png') # 作成したグラフを保存 jpgやpdfも可能

# %% [markdown]
# ## 複数のグラフを表示

# %%
# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

# %%
df.head(100) # 最初の100件表示
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-11-01  22730.490234  22852.720703  22705.599609  22850.769531
# 2019-11-05  23118.789062  23328.519531  23090.939453  23251.990234
# 2019-11-06  23343.509766  23352.560547  23246.570312  23303.820312
# 2019-11-07  23283.140625  23336.000000  23253.320312  23330.320312
# 2019-11-08  23550.039062  23591.089844  23313.410156  23391.869141
# ...                  ...           ...           ...           ...
# 2020-03-26  19234.769531  19240.289062  18512.810547  18664.599609
# 2020-03-27  19021.970703  19389.429688  18832.210938  19389.429688
# 2020-03-30  18884.070312  19084.970703  18578.199219  19084.970703
# 2020-03-31  19181.900391  19336.189453  18834.160156  18917.009766
# 2020-04-01  18686.119141  18784.250000  17871.619141  18065.410156
#
#                Adj Close     Volume         sma05         sma25
# Date
# 2019-11-01  22850.769531   65400000           NaN           NaN
# ...

# %%
# 上の移動平均をグラフに表示
plt.figure(figsize=(30, 10))
plt.plot(x, y, label='close')
plt.plot(x, df['sma05'], label='sma05')
plt.plot(x, df['sma25'], label='sma25')
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()
plt.legend()
plt.title('日経平均株価2019-2020', fontsize=35)
# Out:
# Text(0.5, 1.0, '日経平均株価2019-2020')

# %%
# グラフ色変更
plt.figure(figsize=(30, 10))
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()
plt.legend()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.show()

# %%
# 凡例サイズ変更（大きくする）
plt.figure(figsize=(30, 10))
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price', fontsize=30)
plt.grid()
plt.legend(fontsize=20)
plt.title('日経平均株価2019-2020', fontsize=35)
plt.savefig('N225_1.png')
