# %%
import pandas as pd

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルの'Date'列をインデックスにし、
日付型に設定してデータフレームとして読み込む。
上位10件を表示
"""
df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')
df.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-11-01  22730.49023  22852.72070  22705.59961  22850.76953  22850.76953
# 2019-11-05  23118.78906  23328.51953  23090.93945  23251.99023  23251.99023
# 2019-11-06  23343.50977  23352.56055  23246.57031  23303.82031  23303.82031
# 2019-11-07  23283.14063  23336.00000  23253.32031  23330.32031  23330.32031
# 2019-11-08  23550.03906  23591.08984  23313.41016  23391.86914  23391.86914
# 2019-11-11  23422.13086  23471.82031  23323.01953  23331.83984  23331.83984
# 2019-11-12  23336.36914  23545.69922  23312.25000  23520.00977  23520.00977
# 2019-11-13  23439.25000  23452.63086  23270.92969  23319.86914  23319.86914
# 2019-11-14  23325.50000  23360.06055  23062.16016  23141.55078  23141.55078
# 2019-11-15  23160.52930  23340.76953  23121.58984  23303.32031  23303.32031
#
#                Volume
# Date
# 2019-11-01   65400000
# 2019-11-05  102100000
# 2019-11-06   77400000
# 2019-11-07   70900000
# ...

# %%
"""
2020年11月2日〜2021年10月29日の米ドル/円の為替データが含まれるcsvファイルの'Date'列をインデックスにし、
日付型に設定してデータフレームとして読み込む。
上位10件を表示。
"""

df = pd.read_csv('csv_files/USDJPY.csv', parse_dates=True, index_col='Date')
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2020-11-02  104.611999  104.943001  104.611999  104.580002  104.580002       0
# 2020-11-03  104.723999  104.801002  104.436997  104.724998  104.724998       0
# 2020-11-04  104.505997  105.341003  104.161003  104.545998  104.545998       0
# 2020-11-05  104.435997  104.449997  103.573998  104.438003  104.438003       0
# 2020-11-06  103.596001  103.758003  103.183998  103.602997  103.602997       0
# 2020-11-09  103.239998  105.636002  103.239998  103.252998  103.252998       0
# 2020-11-10  105.162003  105.477997  104.821999  105.137001  105.137001       0
# 2020-11-11  105.263001  105.660004  105.012001  105.260002  105.260002       0
# 2020-11-12  105.424004  105.471001  105.102997  105.415001  105.415001       0
# 2020-11-13  105.084999  105.144997  104.611000  105.089996  105.089996       0

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
x軸に日付データが入っているインデックス、y軸に日経平均の高値を表す'High'列を指定し、
折れ線グラフを作成する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['High']
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
次に、前日の'Adj Close'列の値との差分を示す列として'Diff'列を作成し、データフレームに追加。
そして、x軸に日付データが入っているインデックス、
y軸に前日の終値との差を表す'Diff'列を指定し、折れ線グラフを作成する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

df['Diff'] = df['Adj Close'].diff() # 調整済みの終値の前日との差分を求める
x = df.index
y = df['Diff']
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
次に、グラフ描画領域全体のサイズを横10インチ、縦5インチで設定する。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
次に、グラフ描画領域全体のサイズを横10インチ、縦5インチで設定する
次に、x軸とy軸の目盛りの文字サイズを15に設定する。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定する。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定する。
・x軸の目盛りの文字サイズを15に設定する。
・y軸の目盛りの表示値を18000, 20000, 22000, 24000とし、文字サイズを15に設定します。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成しましょう。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks([18000, 20000, 22000, 24000],fontsize=15)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸の目盛りの文字サイズを15に設定し、45度回転させて表示。
・y軸の目盛りの文字サイズを15に設定。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
折れ線グラフを作成する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'、文字サイズを30、位置を右端に設定。
・y軸のラベルを'Price'、文字サイズを30、位置を上端、ラベルの向きを水平に設定。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30, loc='right')
plt.ylabel('Price',  fontsize=30, loc='top')
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・x軸とy軸の目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、
y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

plt.figure(figsize=(10, 5))
x = df.index
y = df['Adj Close']
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・y軸のみ、目盛りの位置に赤色の破線のグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid(color='red', linestyle='dotted', axis='y')
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチで設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、赤色で折れ線グラフを作成。
"""
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.plot(x, y, color='red')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチとし、グラフの背景色をライトブルーに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5), facecolor='lightblue')
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチとし、グラフ領域に太さ10の赤色の枠を設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5), linewidth=10, edgecolor='red')
plt.plot(x, y)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
グラフの線の太さを5に設定して折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.plot(x, y, linewidth=5)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
グラフの線の太さを5、透明度を0.5に設定して折れ線グラフを作成。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.plot(x, y, linewidth=5, alpha=0.5)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
グラフの線のスタイルを破線に設定して折れ線グラフを作成。
"""

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.plot(x, y, linestyle='dashed')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示する。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
グラフに円形のマーカーを設定して折れ線グラフを作成する。
"""

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.plot(x, y, marker='o')
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定します。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
グラフに四角形で大きさ10のマーカーを設定して折れ線グラフを作成する。
"""

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.plot(x, y, marker='s', markersize=10)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成する。
"""

import japanize_matplotlib

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.plot(x, y)
plt.title('日経平均株価2019-2020', fontsize=35)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35にし、グラフとの余白を30空けて右端に表示する。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
折れ線グラフを作成する。
"""

x = df.index
y = df['Adj Close']

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.plot(x, y)
# plt.title('日経平均株価2019-2020', fontsize=35, loc='right', y=1.3)
plt.title('日経平均株価2019-2020', fontsize=35, loc='right', pad=30)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・グラフに注釈をつけます。注釈の文字は'point'、矢印の先端の位置は2019年11月18日（データフレームの行番号10）のデータの位置とする。
注釈の一文字目の座標は、x座標が2019年11月28日の位置、y座標が24000円の位置とする。
また、注釈の文字サイズは20、文字の色は赤、矢印の色は黒とする。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、
折れ線グラフを作成する。

・matplotlibライブラリのdatesモジュールをmdatesという名前でインポートする。
・mdatesのdate2num関数を使用して日付型のデータ数値に変換し、matplotlibで扱えるように変換する。
・矢印の設定は辞書型で渡す。
"""

import matplotlib.dates as mdates # 時系列データを取得するためにインポート

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.annotate('point',xy=(mdates.date2num(x[10]),y[10]),
              xytext=(mdates.date2num(x[10])+10,24000), fontsize=20, color='red', arrowprops=dict(color='black'))
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸とy軸の目盛りの文字サイズを15に設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・グラフに注釈をつける。注釈の文字は'point'、矢印の先端の位置は2020年4月2日（データフレームの行番号100）のデータの位置とする。
  注釈の一文字目の座標は、x座標を矢印先端より30日分右の位置、y座標を19000円の位置とする。
  また、注釈の文字サイズは20、文字の色は赤、矢印の色は黒とします。また矢印の先端は「^」字型にする。
そして、x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、折れ線グラフを作成する。

・matplotlibライブラリのdatesモジュールをmdatesという名前でインポートする。
・mdatesのdate2num関数を使用して日付型のデータを数値に変換し、matplotlibで扱えるように変換する。
・矢印の設定は辞書型で渡す。
"""

import matplotlib.dates as mdates # 時系列データを取得するためにインポート

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.annotate('point',
             xy=(mdates.date2num(x[100]), y[100]),
             xytext=(mdates.date2num(x[100])+30, 19000), 
             fontsize=20,
             color='red', 
             arrowprops=dict(color='black', arrowstyle='->'))
plt.plot(x, y)
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、
25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加する。
作成したデータフレームの上位30件を表示する。

・rollingメソッドとmeanメソッドで移動平均を算出。
・5日移動平均とは、当日から過去5日間の終値の合計値を5で割った値。
　25日移動平均も同様に過去25日の終値の合計値を25で割った値。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

df.head(30)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-11-01  22730.49023  22852.72070  22705.59961  22850.76953  22850.76953
# 2019-11-05  23118.78906  23328.51953  23090.93945  23251.99023  23251.99023
# 2019-11-06  23343.50977  23352.56055  23246.57031  23303.82031  23303.82031
# 2019-11-07  23283.14063  23336.00000  23253.32031  23330.32031  23330.32031
# 2019-11-08  23550.03906  23591.08984  23313.41016  23391.86914  23391.86914
# 2019-11-11  23422.13086  23471.82031  23323.01953  23331.83984  23331.83984
# 2019-11-12  23336.36914  23545.69922  23312.25000  23520.00977  23520.00977
# 2019-11-13  23439.25000  23452.63086  23270.92969  23319.86914  23319.86914
# 2019-11-14  23325.50000  23360.06055  23062.16016  23141.55078  23141.55078
# 2019-11-15  23160.52930  23340.76953  23121.58984  23303.32031  23303.32031
# 2019-11-18  23304.25000  23420.61914  23271.28906  23416.75977  23416.75977
# ...

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の過去20日の最高値と最安値を抽出したカラムをそれぞれ'high20'、'low20'として追加する。
作成したデータフレームの上位30件を表示させてみましょう。

・rollingメソッドとmaxメソッドで最高値を抽出します。
・rollingメソッドとminメソッドで最安値を抽出します。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

# 過去20日の最高値と最安値
past_20_days = 20
df['high20'] = y.rolling(window=past_20_days).max() # pandasのrollingメソッド
df['low'] = y.rolling(window=past_20_days).min()

df.head(30)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-11-01  22730.49023  22852.72070  22705.59961  22850.76953  22850.76953
# 2019-11-05  23118.78906  23328.51953  23090.93945  23251.99023  23251.99023
# 2019-11-06  23343.50977  23352.56055  23246.57031  23303.82031  23303.82031
# 2019-11-07  23283.14063  23336.00000  23253.32031  23330.32031  23330.32031
# 2019-11-08  23550.03906  23591.08984  23313.41016  23391.86914  23391.86914
# 2019-11-11  23422.13086  23471.82031  23323.01953  23331.83984  23331.83984
# 2019-11-12  23336.36914  23545.69922  23312.25000  23520.00977  23520.00977
# 2019-11-13  23439.25000  23452.63086  23270.92969  23319.86914  23319.86914
# 2019-11-14  23325.50000  23360.06055  23062.16016  23141.55078  23141.55078
# 2019-11-15  23160.52930  23340.76953  23121.58984  23303.32031  23303.32031
# 2019-11-18  23304.25000  23420.61914  23271.28906  23416.75977  23416.75977
# ...

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加する。
続いて、以下の通りにグラフを設定する。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'とした折れ線グラフを作成。
・グラフの凡例を表示。
そして、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示する。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close')
plt.plot(x, df['sma05'], label='sma05')
plt.plot(x, df['sma25'], label='sma25')
plt.legend() # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の過去20日の最高値と最安値を抽出したカラムをそれぞれ'high20'、'low20'として追加。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に過去20日の最高値を表す'high20'列を指定し、凡例を'high20'とした折れ線グラフを作成。
次に、x軸に日付データが入っているインデックス、y軸に過去20日の最安値を表す'low20'列を指定し、凡例を'low20'とした折れ線グラフを作成。
・グラフの凡例を表示する。
そして、完成イメージの通りに、調整済み終値、過去20日の最高値、過去20日の最安値を表す折れ線グラフを表示する。
"""

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span20 = 20

df['high20'] = y.rolling(window=span20).max()
df['low20'] = y.rolling(window=span20).min()

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close')
plt.plot(x, df['high20'], label='high20')
plt.plot(x, df['low20'], label='low20')
plt.legend() # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加します。
続いて、以下の通りにグラフを設定する。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定する。
・x軸のラベルを'Date'とし、文字サイズを30に設定する。
・y軸のラベルを'Price'とし、文字サイズを30に設定する。
・目盛りの位置にグリッドを表示する。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定する。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'、カラーコードを'#A29FB4'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'、カラーコードを'#BB6541'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'、カラーコードを'#B99277'とした折れ線グラフを作成。
・グラフの凡例を表示する。
そして、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示する
"""

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.legend() # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示する。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定する。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、判例を'close'、赤色の破線で折れ線グラフを作成する。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'、青色の一点鎖線（直線と点との交互の線）で折れ線グラフを作成する。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'、緑色の点線で折れ線グラフを作成する。
・グラフの凡例を表示する。
そして、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示。
"""

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close', color='red', linestyle='--') # -- 破線
plt.plot(x, df['sma05'], label='sma05', color='blue', linestyle='-.') # -. 一点鎖線
plt.plot(x, df['sma25'], label='sma25', color='green',linestyle=':')  # : 点線
plt.legend() # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'、カラーコードを'#A29FB4'とした折れ線グラフを作成する。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'、カラーコードを'#BB6541'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'、カラーコードを'#B99277'とした折れ線グラフを作成。
・文字サイズを20に設定して、グラフの凡例を表示。
そして、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示する。
"""

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.legend(fontsize=20) # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加する。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示する。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'、カラーコードを'#A29FB4'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'、カラーコードを'#BB6541'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'、カラーコードを'#B99277'とした折れ線グラフを作成。
・文字サイズを20に設定し、グラフの中央下部に1行で凡例を表示する。
そして、完成イメージの通りに、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示する。
"""

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.legend(fontsize=20, loc='lower center', ncol=3) # グラフの中に凡例を表示
plt.show()

# %%
"""
2019年11月1日〜2020年10月30日の日経平均株価のデータが含まれるcsvファイルがある。
まず、このファイルの'Date'列をインデックスにし、日付型に設定してデータフレームとして読み込む。
このデータフレームに、日経平均の調整済みの終値を表す'Adj Close'列の5日移動平均と、25日移動平均を計算したカラムをそれぞれ'sma05'、'sma25'として追加する。
続いて、以下の通りにグラフを設定。
・グラフ描画領域全体のサイズを横10インチ、縦5インチに設定。
・x軸のラベルを'Date'とし、文字サイズを30に設定。
・y軸のラベルを'Price'とし、文字サイズを30に設定。
・目盛りの位置にグリッドを表示する。
・グラフに'日経平均株価2019-2020'とタイトルをつけ、文字サイズを35に設定。
・x軸に日付データが入っているインデックス、y軸に日経平均の調整済みの終値を表す'Adj Close'列を指定し、凡例を'close'、カラーコードを'#A29FB4'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に5日移動平均を表す'sma05'列を指定し、凡例を'sma05'、カラーコードを'#BB6541'とした折れ線グラフを作成。
・x軸に日付データが入っているインデックス、y軸に25日移動平均を表す'sma25'列を指定し、凡例を'sma25'、カラーコードを'#B99277'とした折れ線グラフを作成。
・凡例のタイトルを'グラフの種類'、凡例のタイトルの文字サイズを20、凡例の文字サイズを15に設定して表示。
そして、調整済み終値、5日移動平均線、25日移動平均線の折れ線グラフを表示する。
"""

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
# %matplotlib inline

df = pd.read_csv('csv_files/N225.csv', parse_dates=True, index_col='Date')

x= df.index
y = df['Adj Close'] 

# 移動平均線追加（5日,25日）
span05 = 5
span25 = 25

df['sma05'] = y.rolling(window=span05).mean() # pandasのrollingメソッド
df['sma25'] = y.rolling(window=span25).mean()

plt.figure(figsize=(10, 5))
plt.xlabel('Data', fontsize=30)
plt.ylabel('Price',  fontsize=30)
plt.grid()
plt.title('日経平均株価2019-2020', fontsize=35)
plt.plot(x, y, label='close', color='#A29FB4')
plt.plot(x, df['sma05'], label='sma05', color='#BB6541')
plt.plot(x, df['sma25'], label='sma25', color='#B99277')
plt.legend(title='グラフの種類', title_fontsize=20, fontsize=15) # グラフの中に凡例を表示
plt.show()
